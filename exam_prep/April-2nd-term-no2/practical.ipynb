# %% [markdown]
# 90 point exam
# 5-10 point each "what is tee output"
#
# what is OOP
# what is OOA, OOD
# Abstraction
# Encapsulation, property, name mangling (__)
# How to break encapsulation
# Hierarchy
# Inheritance, types, diamond problem, MRO
# Polymorphism - Duck typing(register, Protocol)
# Object - state, behavior, identity
# Object operations - constructor, Selector, Mutator, Iterator
# Object and class relationships
# -Class
# inheritance
# composition
# aggregation
#
# -Object
# link
# aggregation
#
# Hierarchy modularity
# Static method, Class method
# `__slots__, __call__, __new__`
# Abstract, Interface classes, ABC
# super (error with arguments)
#
# `__str__`, `__repr__`
#
# class attribute, object attribute
#
# staticmethod
#
# Singletone
# class attrubute vs instance attribute
#
# #

# %% [markdown]
# # what is OOP

# %%
Null = None

# %%
class A:
    ...

# class B(A): #is a
#     ...

# class C:
#     def __init__(self):
#         self.b = B() #composition


x = A()
class D:
    def __init(self):
        self.some = x #aggregation


d = D()
print(d.some)
