# %%
dicto = {}

exec('''
def __init__(self):
    print("hiiii")
''',globals(), dicto)

Person = type("Person", (object,), dicto)

p = Person()

print(dicto)

# type(type(Person))
type(object)
type((type('class chka')))
# Out:
# hiiii
# {'__init__': <function __init__ at 0x000001F793448860>}
# type
